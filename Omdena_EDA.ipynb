# %% [markdown]
# <a href="https://colab.research.google.com/github/OmdenaAI/omdena-mumbai-chapter-air-quality/blob/Param/Omdena_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1> For Colaba station Mumbai </h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
url = "/content/ColabaMumbaiMPCB.csv"
df1 = pd.read_csv(url, index_col=0)
print(df1.isnull())

msno.matrix(df1)
# Out:
#        From Date  To Date  PM2.5  PM10     NO    NO2    NOx    NH3    SO2  \
# 1          False    False  False  True  False  False  False  False   True
# 2          False    False  False  True  False  False  False  False  False
# 3          False    False  False  True  False  False  False  False  False
# 4          False    False  False  True  False  False  False  False  False
# 5          False    False  False  True  False  False  False  False  False
# ...          ...      ...    ...   ...    ...    ...    ...    ...    ...
# 76385      False    False   True  True   True   True   True   True   True
# 76386      False    False   True  True   True   True   True   True   True
# 76387      False    False   True  True   True   True   True   True   True
# 76388      False    False   True  True   True   True   True   True   True
# 76389      False    False   True  True   True   True   True   True   True
#
#           CO  ...  Toluene  Eth-Benzene  MP-Xylene     RH     WS     WD  \
# ...

# %%
msno.heatmap(df1)
# Out:
# <Axes: >

# %% [markdown]
# <h1> For Bandra Station

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
url = "/content/BandraMumbaiMPCB.csv"
df2 = pd.read_csv(url, index_col=0)
df2.isnull()
msno.matrix(df2)
# Out:
# <Axes: >

# %%
msno.heatmap(df2)
# Out:
# <Axes: >

# %% [markdown]
# <h1>For Borivali East Station</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
url = "/content/BorivaliEastMumbaiMPCB.csv"
df3 = pd.read_csv(url, index_col=0)
df3.isnull()
msno.matrix(df3)
# Out:
# <Axes: >

# %%
msno.heatmap(df3)
# Out:
# <Axes: >

# %% [markdown]
# <h1>For Bandra Kurla Station Mumbai</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
url = "/content/BandraKurlaComplexMumbaiIITM.csv"
df = pd.read_csv(url, index_col=0)
#df.info()
msno.matrix(df)
# Out:
# <Axes: >

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# <h1>Mazgaon Station</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
url = "/content/MazgaonMumbaiIITM.csv"
df4= pd.read_csv(url, index_col=0)
print(df4.isnull())
msno.matrix(df4)
# Out:
#        FromDate  ToDate  PM2.5   PM10     NO    NO2    NOx    NH3    SO2  \
# 1         False   False  False  False  False  False  False  False  False
# 2         False   False  False  False  False  False  False  False  False
# 3         False   False  False  False  False  False  False  False  False
# 4         False   False  False  False  False  False  False  False  False
# 5         False   False  False  False  False  False  False  False  False
# ...         ...     ...    ...    ...    ...    ...    ...    ...    ...
# 76389     False   False  False  False  False  False  False  False  False
# 76390     False   False  False  False  False  False  False  False  False
# 76391     False   False  False  False  False  False  False  False  False
# 76392     False   False  False  False  False  False  False  False  False
# 76393     False   False  False  False  False  False  False  False  False
#
#           CO  Ozone  Benzene  Toluene  Eth-Benzene  MP-Xylene    RH     WS  \
# ...

# %%
msno.heatmap(df4)
# Out:
# <Axes: >

# %% [markdown]
# <h1>Vile Parle West</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
url = "/content/VileParleWestMumbaiMPCB.csv"
df5= pd.read_csv(url, index_col=0)
df5.isnull()
msno.matrix(df5)
# Out:
# <Axes: >

# %%
msno.heatmap(df5)
# Out:
# <Axes: >

# %% [markdown]
# <h1> Navy Nagar Station </h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
url = "/content/NavyNagarColabaMumbaiIITM.csv"
df6= pd.read_csv(url, index_col=0)
df6.isnull()
msno.matrix(df6)
# Out:
# <Axes: >

# %%
msno.heatmap(df6)
# Out:
# <Axes: >
