# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the dataset
df = pd.read_csv(r"F:\omdena-mumbai-chapter-air-quality\src\data\air-quality-india.csv")
df.head()
# Out:
#              Timestamp  Year  Month  Day  Hour   PM2.5
# 0  2017-11-07 12:00:00  2017     11    7    12   64.51
# 1  2017-11-07 13:00:00  2017     11    7    13   69.95
# 2  2017-11-07 14:00:00  2017     11    7    14   92.79
# 3  2017-11-07 15:00:00  2017     11    7    15  109.66
# 4  2017-11-07 16:00:00  2017     11    7    16  116.50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36192 entries, 0 to 36191
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  36192 non-null  object
#  1   Year       36192 non-null  int64
#  2   Month      36192 non-null  int64
#  3   Day        36192 non-null  int64
#  4   Hour       36192 non-null  int64
#  5   PM2.5      36192 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.7+ MB

# %%
df['Year'].value_counts()
# Out:
# 2020    8356
# 2021    8283
# 2019    7685
# 2018    7537
# 2022    3194
# 2017    1137
# Name: Year, dtype: int64

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36192 entries, 0 to 36191
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Timestamp  36192 non-null  datetime64[ns]
#  1   Year       36192 non-null  int64
#  2   Month      36192 non-null  int64
#  3   Day        36192 non-null  int64
#  4   Hour       36192 non-null  int64
#  5   PM2.5      36192 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(4)
# memory usage: 1.7 MB

# %%
plt.figure(figsize=(10,10))
plt.plot(df['Timestamp'], df['PM2.5'], linewidth=2, markersize=12, linestyle='--')
plt.show()

# %% [markdown]
# **Key points to note:**
#
# 1. There's a seasonality in PM2.5 pollutant concentration during last quarter of the year
# 2. Time series decomposition can be used to identify difference between all the components
# 3. SARIMAX model can be used to take effect of seasonality in forecasting model
# 4. Build forecasting model every pollutant to forecast AQI and Build forecasting model for AQI.
