# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime as dt

# %% [markdown]
# ### Reading from csv file
# Source : https://www.kaggle.com/code/ayushv322/air-quality-india-exploratory-data-analysis

# %%
df = pd.read_csv("/Users/imsc/OmdenaAI/omdena-mumbai-chapter-air-quality/src/data/data.csv",
                 encoding="ISO-8859-1")
df.fillna(0, inplace = True)
df.head()
# Out:
# /var/folders/sq/k10xxh994030zckw60__y7700000gn/T/ipykernel_29937/3246888678.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/imsc/OmdenaAI/omdena-mumbai-chapter-air-quality/src/data/data.csv",
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad      0
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad      0
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   0.0  0.0
# 1                     Industrial Area  3.1   7.0   0.0  0.0
# 2  Residential, Rural and other Areas  6.2  28.5   0.0  0.0
# ...

# %%
df.shape
# Out:
# (435742, 13)

# %%
sns.lineplot(x="date", y = 'so2', 
             data=df[df['location'] == 'Mumbai'])
# Out:
# <Axes: xlabel='date', ylabel='so2'>

# %%
df.dtypes
# Out:
# stn_code                        object
# sampling_date                   object
# state                           object
# location                        object
# agency                          object
# type                            object
# so2                            float64
# no2                            float64
# rspm                           float64
# spm                            float64
# location_monitoring_station     object
# pm2_5                          float64
# date                            object
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# %%
df.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad      0
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad      0
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   0.0  0.0
# 1                     Industrial Area  3.1   7.0   0.0  0.0
# 2  Residential, Rural and other Areas  6.2  28.5   0.0  0.0
# 3  Residential, Rural and other Areas  6.3  14.7   0.0  0.0
# 4                     Industrial Area  4.7   7.5   0.0  0.0
#
#   location_monitoring_station  pm2_5       date
# 0                           0    0.0 1990-02-01
# 1                           0    0.0 1990-02-01
# 2                           0    0.0 1990-02-01
# ...

# %%
df.dtypes
# Out:
# stn_code                               object
# sampling_date                          object
# state                                  object
# location                               object
# agency                                 object
# type                                   object
# so2                                   float64
# no2                                   float64
# rspm                                  float64
# spm                                   float64
# location_monitoring_station            object
# pm2_5                                 float64
# date                           datetime64[ns]
# dtype: object

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# %%
df.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad      0
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad      0
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad      0
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   0.0  0.0
# 1                     Industrial Area  3.1   7.0   0.0  0.0
# 2  Residential, Rural and other Areas  6.2  28.5   0.0  0.0
# 3  Residential, Rural and other Areas  6.3  14.7   0.0  0.0
# 4                     Industrial Area  4.7   7.5   0.0  0.0
#
#   location_monitoring_station  pm2_5       date  year  month
# 0                           0    0.0 1990-02-01  1990      2
# 1                           0    0.0 1990-02-01  1990      2
# ...

# %%
df[(df['location'] == 'Mumbai') & df['pm2_5'] > 0]
# Out:
# Empty DataFrame
# Columns: [stn_code, sampling_date, state, location, agency, type, so2, no2, rspm, spm, location_monitoring_station, pm2_5, date, year, month]
# Index: []
