# %% [markdown]
# # AQI FORECASTING :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import os

from darts import TimeSeries,concatenate
from darts.utils.missing_values import fill_missing_values
from darts.dataprocessing.transformers import Scaler, MissingValuesFiller
from darts.metrics import mape
from darts.utils.statistics import plot_acf, check_seasonality
from darts.models import NaiveSeasonal
from darts.models import RNNModel,BlockRNNModel,TFTModel
from darts.utils.likelihood_models import QuantileRegression

# %matplotlib inline
plt.rcParams["figure.figsize"] = (20, 12)

import warnings
warnings.filterwarnings("ignore")

import logging
logging.disable(logging.CRITICAL)

# %% [markdown]
# ## CLEANING & PREPROCESSING THE DATA :

# %%
dataframe = pd.read_csv('C:/Users/santh/Downloads/csv_aqi/KhindipadaBhandupWestMumbaiIITM.csv')

# %%
#dataframe.dtypes

# %%
#Cleaning the Data :

def clean_data(df):

    df = df.drop(['AQI_bucket_calculated'], axis=1) 
    df.drop(df.tail(1).index,inplace = True)
    df['Date'] = df['Date'].astype(str)
    return df

# %%
df = clean_data(dataframe)

# %%
df.tail()
# Out:
#        Unnamed: 0                 Date   PM2.5    PM10    NO    NO2   NOx  \
# 76315       76315  2023-03-06 23:00:00  184.11  374.68  0.33  10.89  5.79
# 76316       76316  2023-03-06 23:15:00  109.55  223.10  2.00  13.12  6.98
# 76317       76317  2023-03-06 23:30:00   43.17   94.31  1.00  12.46  6.63
# 76318       76318  2023-03-06 23:45:00   31.82   71.65  0.90   5.55  6.45
# 76319       76319  2023-03-07 00:00:00     NaN     NaN   NaN    NaN   NaN
#
#          NH3    SO2    CO  ...  NH3_24hr_avg  CO_8hr_max  Ozone_8hr_max  \
# 76315  11.34  13.16  1.65  ...     11.866087        1.65           76.0
# 76316  11.47  12.76  1.66  ...     11.988696        1.66           76.0
# 76317  11.59  11.38  1.61  ...     11.977826        1.66           68.0
# 76318   8.29   4.33  1.67  ...     11.784348        1.67           67.0
# 76319    NaN    NaN   NaN  ...     11.755455        1.67           67.0
#
#        PM2.5_SubIndex  PM10_SubIndex  SO2_SubIndex  NOx_SubIndex  \
# ...

# %%
# Creating a TimeSeries object from the hourly data

df['Date'] = pd.to_datetime(df['Date'])

df = df.set_index('Date')
df_hourly = df.resample('H').mean().reset_index()

# %%
ts_aqi = TimeSeries.from_dataframe(df=df_hourly, 
                                   time_col='Date', 
                                   value_cols= ['AQI_calculated'], 
                                   fill_missing_dates=True, 
                                   freq='H')

# %%
#Checking for missing values:

missing_values = df_hourly['AQI_calculated'].isna().sum()
print(f'AQI calculated column have {missing_values} Missing Values')
# Out:
# AQI calculated column have 1192 Missing Values

# %%
ts_aqi.plot()
plt.title('Hourly AQI Values')
# Out:
# Text(0.5, 1.0, 'Hourly AQI Values')

# %%
#Filling the Missing Values:

filler = MissingValuesFiller()
scaler = Scaler()


series = scaler.fit_transform(filler.transform(ts_aqi)).astype(np.float32)
series.plot()
plt.title("Hourly AQI after Filling Missing Values")
# Out:
# Text(0.5, 1.0, 'Hourly AQI after Filling Missing Values')

# %%
#Function to display the time series plot and summary statistics:

def display_forecast(pred_series, ts_transformed, forecast_type, start_date=None):
    plt.figure(figsize=(15, 10))
    if start_date:
        ts_transformed = ts_transformed.drop_before(start_date)
    ts_transformed.univariate_component(0).plot(label="actual")
    pred_series.plot(label=("historic " + forecast_type + " forecasts"))
    plt.title(f"Mean Absolute Percentage Error = {(mape(ts_transformed.univariate_component(0), pred_series).round(2))}%")
    plt.legend()

# %% [markdown]
# ## AQI FORECASTING :

# %%
#Creating a train-test split:
train,val = series.split_after(pd.Timestamp("20221001"))

train.plot(label= f"Training Data = {len(train)}")
val.plot(label= f"Validation Data = {len(val)}")

# %% [markdown]
# ## BASELINE Method (NaiveSeasonal)  :

# %%
#Creating and fitting the model:

naive_model = NaiveSeasonal(K=1)
naive_model.fit(train)
naive_forecast = naive_model.predict(len(val))

display_forecast(naive_forecast, series, "naive", start_date=pd.Timestamp("20221001"))

# %% [markdown]
# We could see that our baseline model, which just repeats the previous value for the following ,Fails to forecast correctly and has a MAPE of 77.07% & k = 1 where the model “repeats” the value that occured K time steps ago.

# %% [markdown]
# ### Inspect Seasonality :

# %%
for m in range(2, 25):
    is_seasonal, period = check_seasonality(train, m=m, alpha=0.05)
    if is_seasonal:
        print("There is seasonality of order {}.".format(period))
# Out:
# There is seasonality of order 23.

# %%
plot_acf(train, m=23, alpha=0.05)

# %%
seasonal_model = NaiveSeasonal(K=23)
seasonal_model.fit(train)
seasonal_forecast = seasonal_model.predict(len(val))

display_forecast(seasonal_forecast, series, "naive_seasonal", start_date=pd.Timestamp("20221001"))

# %% [markdown]
# Hence, the revised "K" model performs terribly compared to the simple Naive seasonal model, and the function fails to accurately predict seasonality in our data.

# %% [markdown]
# ## Adding Co-variates:

# %%
df_hourly.columns
# Out:
# Index(['Date', 'Unnamed: 0', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'SO2',
#        'CO', 'Ozone', 'Benzene', 'Toluene', 'Eth-Benzene', 'MP-Xylene', 'RH',
#        'WS', 'WD', 'BP', 'Xylene', 'AT', 'RF', 'TOT-RF', 'PM10_24hr_avg',
#        'PM2.5_24hr_avg', 'SO2_24hr_avg', 'NOx_24hr_avg', 'NH3_24hr_avg',
#        'CO_8hr_max', 'Ozone_8hr_max', 'PM2.5_SubIndex', 'PM10_SubIndex',
#        'SO2_SubIndex', 'NOx_SubIndex', 'NH3_SubIndex', 'Checks',
#        'AQI_calculated'],
#       dtype='object')

# %%
ts_pm25 = TimeSeries.from_dataframe(df_hourly, "Date", "PM2.5")
ts_pm10 = TimeSeries.from_dataframe(df_hourly, "Date", "PM10")
ts_no2 = TimeSeries.from_dataframe(df_hourly, "Date", "NO2")
ts_so2 = TimeSeries.from_dataframe(df_hourly, "Date", "SO2")
ts_co = TimeSeries.from_dataframe(df_hourly, "Date", "CO")
ts_ozone = TimeSeries.from_dataframe(df_hourly, "Date", "Ozone")

# %%
ts_pm25 = fill_missing_values(ts_pm25)
ts_pm10 = fill_missing_values(ts_pm10)
ts_no2 = fill_missing_values(ts_no2)
ts_so2 = fill_missing_values(ts_so2)
ts_co = fill_missing_values(ts_co)
ts_ozone = fill_missing_values(ts_ozone)

# %% [markdown]
# ## TFT Model :

# %%
# before starting, we define some constants
num_samples = 200

figsize = (9, 6)
lowest_q, low_q, high_q, highest_q = 0.01, 0.1, 0.9, 0.99
label_q_outer = f"{int(lowest_q * 100)}-{int(highest_q * 100)}th percentiles"
label_q_inner = f"{int(low_q * 100)}-{int(high_q * 100)}th percentiles"

# %%
#split the data:
training_cutoff = pd.Timestamp("20221001")
train, val = series.split_after(training_cutoff)

# Normalize the time series (note: we avoid fitting the transformer on the validation set)
transformer = Scaler()
train_transformed = transformer.fit_transform(train)
val_transformed = transformer.transform(val)
series_transformed = transformer.transform(series)

# create covariate series
covariates = ts_pm25.stack(ts_pm10).stack(ts_no2).stack(ts_so2).stack(ts_co).stack(ts_ozone)
covariates = covariates.astype(np.float32)

# transform covariates (note: we fit the transformer on train split and can then transform the entire covariates series)
scaler_covs = Scaler()
cov_train, cov_val = covariates.split_after(training_cutoff)
scaler_covs.fit(cov_train)
covariates_transformed = scaler_covs.transform(covariates)

# %%
# default quantiles for QuantileRegression
quantiles = [
    0.01,
    0.05,
    0.1,
    0.15,
    0.2,
    0.25,
    0.3,
    0.4,
    0.5,
    0.6,
    0.7,
    0.75,
    0.8,
    0.85,
    0.9,
    0.95,
    0.99,
]
input_chunk_length = 24
forecast_horizon = 12


my_model = TFTModel(
    input_chunk_length=input_chunk_length,
    output_chunk_length=forecast_horizon,
    hidden_size=64,
    lstm_layers=1,
    num_attention_heads=4,
    dropout=0.1,
    batch_size=16,
    n_epochs=300,
    add_relative_index=False,
    add_encoders=None,
    likelihood=QuantileRegression(
        quantiles=quantiles
    ),  # QuantileRegression is set per default
    # loss_fn=MSELoss(),
    random_state=42,
)

# %%
my_model.fit(train_transformed, future_covariates=covariates_transformed,epochs=300, verbose=True)
# Out:
# Training: 0it [00:00, ?it/s]

# %%
def eval_model(model, n, actual_series, val_series):
    pred_series = model.predict(n=n, num_samples=num_samples)

    # plot actual series
    plt.figure(figsize=figsize)
    actual_series[: pred_series.end_time()].plot(label="actual")

    # plot prediction with quantile ranges
    pred_series.plot(
        low_quantile=lowest_q, high_quantile=highest_q, label=label_q_outer
    )
    pred_series.plot(low_quantile=low_q, high_quantile=high_q, label=label_q_inner)

    plt.title("MAPE: {:.2f}%".format(mape(val_series, pred_series)))
    plt.legend()


eval_model(my_model, len(val_transformed), series_transformed, val_transformed)
# Out:
# Predicting: 0it [00:00, ?it/s]

# %%
tft_forecast = my_model.predict(len(val_transformed),num_samples=num_samples)

display_forecast(tft_forecast, series_transformed, "tft_model", start_date=pd.Timestamp("20221001"))
# Out:
# Predicting: 0it [00:00, ?it/s]

# %%
path = 'C:/Users/santh/Downloads/tft_model_100epoch' 
tft_model.save(path)

print(f'Model saved at {path}')

# %%
backtest_series = my_model.historical_forecasts(
    series_transformed,
    future_covariates=covariates_transformed,
    start=train.end_time() + train.freq,
    num_samples=num_samples,
    forecast_horizon=forecast_horizon,
    stride=forecast_horizon,
    last_points_only=False,
    retrain=False,
    verbose=True,
)
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# ...

# %%
def eval_backtest(backtest_series, actual_series, horizon, start, transformer):
    plt.figure(figsize=figsize)
    actual_series.plot(label="actual")
    backtest_series.plot(
        low_quantile=lowest_q, high_quantile=highest_q, label=label_q_outer
    )
    backtest_series.plot(low_quantile=low_q, high_quantile=high_q, label=label_q_inner)
    plt.legend()
    plt.title(f"Backtest, starting {start}, {horizon}-months horizon")
    print(
        "MAPE: {:.2f}%".format(
            mape(
                transformer.inverse_transform(actual_series),
                transformer.inverse_transform(backtest_series),
            )
        )
    )


eval_backtest(
    backtest_series=concatenate(backtest_series),
    actual_series=series_transformed,
    horizon=forecast_horizon,
    start=training_cutoff,
    transformer=transformer,
)
# Out:
# MAPE: 10.13%
